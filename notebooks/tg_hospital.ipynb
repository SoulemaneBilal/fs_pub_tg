# %%
import ast
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.wkt import loads

# %%
df = pd.read_csv("Forma", encoding='ISO-8859-1')
df.sample(5)
# Out:
#       Unnamed: 0      long region_nom_bdd prefecture_nom_bdd commune_nom_bdd  \
# 646          646  8.655323       Centrale          Sotouboua     Sotouboua 2
# 1331        1331  6.883016       Plateaux               Agou          Agou 1
# 2268        2268  6.175230       Maritime              Golfe         Golfe 2
# 591          591  7.745386       Plateaux            AniÃÂ©       AniÃÂ© 2
# 1740        1740  6.237888       Maritime                 Vo            Vo 2
#
#             canton_nom_bdd        nom_localite  \
# 646            AdjengrÃÂ©           Sotouboua
# 1331  Agou-Nyogbo-Dzidjole  Agou / agou nyogbo
# 2268          BÃÂ¨-Centre         Hedzranawoe
# 591           AdogbÃÂ©nou                Anie
# 1740             Togoville                  Vo
#
#                                                  nom_fs  \
# 646   Centre de Sante Vie Nouvelle - CMS Association...
# 1331                                   Hopital Bethesda
# ...
